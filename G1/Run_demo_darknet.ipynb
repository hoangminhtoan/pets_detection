# %% [markdown]
# # Step1: Connect to google drive & run script
#
# ```
# function ClickConnect(){
# console.log("Working");
# document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click();
# }
# setInterval(ClickConnect,60000)
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# verify CUDA
# !/usr/local/cuda/bin/nvcc --version
# !nvidia-smi
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0
# Wed Sep 22 05:15:24 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   73C    P8    12W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Step 2: Run Testing Model

# %%
# %cd /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/
# !chmod +x ./darknet
# !chmod +x *.sh
# !bash run_darknet_pets_n.sh
# !bash run_darknet_pets_p.sh
# Out:
# Streaming output truncated to the last 5000 lines.
#   34 conv    128       1 x 1/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.044 BF
#   35 conv    256       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 256 0.793 BF
#   36 conv    128       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.088 BF
#   37 upsample                 2x    48 x  28 x 128 ->   96 x  56 x 128
#   38 route  37 15 	                           ->   96 x  56 x 256
#   39 conv     64       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  64 0.176 BF
#   40 conv    256       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x 256 1.585 BF
#   41 route  0 		                           ->  384 x 224 x  32
#   42 avg                4x 4/ 4    384 x 224 x  32 ->   96 x  56 x  32 0.003 BF
#   43 route  42 40 	                           ->   96 x  56 x 288
#   44 conv    128       1 x 1/ 1     96 x  56 x 288 ->   96 x  56 x 128 0.396 BF
#   45 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   46 conv    128       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x 128 0.352 BF
#   47 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   48 conv   1152       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x1152 3.171 BF
#   49 route  40 		                           ->   96 x  56 x 256
#   50 conv    256       3 x 3/ 1     96 x  56 x 256 ->   96 x  56 x 256 6.342 BF
#   51 conv     63       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  63 0.173 BF
#   52 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#  embedding_layer_id = 48,  embedding_size = 128
#   53 route  48 		                           ->   96 x  56 x1152
#   54  max_contr_size = 0 MB
# contrastive   96 x  56 x   9 x emb_size  128 x batch:    1  classes =    2, step = 48384
# detection
# Total BFLOPS 31.950
# avg_outputs = 1067184
#  Allocate additional workspace_size = 26.22 MB
#  Try to load weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights
# Loading weights from backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights...
#  seen 64, trained: 640 K-images (10 Kilo-batches_64)
# Done! Loaded 55 layers from weights-file
# Loaded - names_list: /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/backup/20210920_yolov4_tiny_tracking/pets.names, classes = 2
# input video /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N059.mp4 with frame rate: 10.0 => skips 1 frame(s)
# Testing video 39 / 54
# Namespace(config_file='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg', data_file='backup/20210920_yolov4_tiny_tracking/pets.data', dont_show=False, ext_output=False, input_type='video', out_filename='', source_url='/content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N060.mp4', thresh=0.5, weights='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights')
#  Try to load cfg: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg, weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights, clear = 0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    768 x 448 x   3 ->  384 x 224 x  32 0.149 BF
#    1 conv     64       3 x 3/ 2    384 x 224 x  32 ->  192 x 112 x  64 0.793 BF
#    2 conv     64       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  64 1.585 BF
#    3 route  2 		                           ->  192 x 112 x  64
#    4 conv     32       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  32 0.793 BF
#    5 conv     32       3 x 3/ 1    192 x 112 x  32 ->  192 x 112 x  32 0.396 BF
#    6 route  5 4 	                           ->  192 x 112 x  64
#    7 conv     64       1 x 1/ 1    192 x 112 x  64 ->  192 x 112 x  64 0.176 BF
#    8 route  2 7 	                           ->  192 x 112 x 128
#    9 max                2x 2/ 2    192 x 112 x 128 ->   96 x  56 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 128 1.585 BF
#   11 route  10 		                           ->   96 x  56 x 128
#   12 conv     64       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x  64 0.793 BF
#   13 conv     64       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x  64 0.396 BF
#   14 route  13 12 	                           ->   96 x  56 x 128
#   15 conv    128       1 x 1/ 1     96 x  56 x 128 ->   96 x  56 x 128 0.176 BF
#   16 route  10 15 	                           ->   96 x  56 x 256
#   17 max                2x 2/ 2     96 x  56 x 256 ->   48 x  28 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 256 1.585 BF
#   19 route  18 		                           ->   48 x  28 x 256
#   20 conv    128       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.793 BF
#   21 conv    128       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.396 BF
#   22 route  21 20 	                           ->   48 x  28 x 256
#   23 conv    256       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 256 0.176 BF
#   24 route  18 23 	                           ->   48 x  28 x 512
#   25 max                2x 2/ 2     48 x  28 x 512 ->   24 x  14 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     24 x  14 x 512 ->   24 x  14 x 512 1.585 BF
#   27 conv    256       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 256 0.088 BF
#   28 conv    256       1 x 1/ 1     24 x  14 x 256 ->   24 x  14 x 256 0.044 BF
#   29 conv    512       3 x 3/ 1     24 x  14 x 256 ->   24 x  14 x 512 0.793 BF
#   30 conv    128       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 128 0.044 BF
#   31 upsample                 2x    24 x  14 x 128 ->   48 x  28 x 128
#   32 route  31 23 	                           ->   48 x  28 x 384
#   33 conv    128       1 x 1/ 1     48 x  28 x 384 ->   48 x  28 x 128 0.132 BF
#   34 conv    128       1 x 1/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.044 BF
#   35 conv    256       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 256 0.793 BF
#   36 conv    128       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.088 BF
#   37 upsample                 2x    48 x  28 x 128 ->   96 x  56 x 128
#   38 route  37 15 	                           ->   96 x  56 x 256
#   39 conv     64       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  64 0.176 BF
#   40 conv    256       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x 256 1.585 BF
#   41 route  0 		                           ->  384 x 224 x  32
#   42 avg                4x 4/ 4    384 x 224 x  32 ->   96 x  56 x  32 0.003 BF
#   43 route  42 40 	                           ->   96 x  56 x 288
#   44 conv    128       1 x 1/ 1     96 x  56 x 288 ->   96 x  56 x 128 0.396 BF
#   45 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   46 conv    128       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x 128 0.352 BF
#   47 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   48 conv   1152       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x1152 3.171 BF
#   49 route  40 		                           ->   96 x  56 x 256
#   50 conv    256       3 x 3/ 1     96 x  56 x 256 ->   96 x  56 x 256 6.342 BF
#   51 conv     63       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  63 0.173 BF
#   52 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#  embedding_layer_id = 48,  embedding_size = 128
#   53 route  48 		                           ->   96 x  56 x1152
#   54  max_contr_size = 0 MB
# contrastive   96 x  56 x   9 x emb_size  128 x batch:    1  classes =    2, step = 48384
# detection
# Total BFLOPS 31.950
# avg_outputs = 1067184
#  Allocate additional workspace_size = 26.22 MB
#  Try to load weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights
# Loading weights from backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights...
#  seen 64, trained: 640 K-images (10 Kilo-batches_64)
# Done! Loaded 55 layers from weights-file
# Loaded - names_list: /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/backup/20210920_yolov4_tiny_tracking/pets.names, classes = 2
# input video /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N060.mp4 with frame rate: 10.0 => skips 1 frame(s)
# Testing video 40 / 54
# Namespace(config_file='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg', data_file='backup/20210920_yolov4_tiny_tracking/pets.data', dont_show=False, ext_output=False, input_type='video', out_filename='', source_url='/content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N061.mp4', thresh=0.5, weights='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights')
#  Try to load cfg: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg, weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights, clear = 0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    768 x 448 x   3 ->  384 x 224 x  32 0.149 BF
#    1 conv     64       3 x 3/ 2    384 x 224 x  32 ->  192 x 112 x  64 0.793 BF
#    2 conv     64       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  64 1.585 BF
#    3 route  2 		                           ->  192 x 112 x  64
#    4 conv     32       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  32 0.793 BF
#    5 conv     32       3 x 3/ 1    192 x 112 x  32 ->  192 x 112 x  32 0.396 BF
#    6 route  5 4 	                           ->  192 x 112 x  64
#    7 conv     64       1 x 1/ 1    192 x 112 x  64 ->  192 x 112 x  64 0.176 BF
#    8 route  2 7 	                           ->  192 x 112 x 128
#    9 max                2x 2/ 2    192 x 112 x 128 ->   96 x  56 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 128 1.585 BF
#   11 route  10 		                           ->   96 x  56 x 128
#   12 conv     64       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x  64 0.793 BF
#   13 conv     64       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x  64 0.396 BF
#   14 route  13 12 	                           ->   96 x  56 x 128
#   15 conv    128       1 x 1/ 1     96 x  56 x 128 ->   96 x  56 x 128 0.176 BF
#   16 route  10 15 	                           ->   96 x  56 x 256
#   17 max                2x 2/ 2     96 x  56 x 256 ->   48 x  28 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 256 1.585 BF
#   19 route  18 		                           ->   48 x  28 x 256
#   20 conv    128       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.793 BF
#   21 conv    128       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.396 BF
#   22 route  21 20 	                           ->   48 x  28 x 256
#   23 conv    256       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 256 0.176 BF
#   24 route  18 23 	                           ->   48 x  28 x 512
#   25 max                2x 2/ 2     48 x  28 x 512 ->   24 x  14 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     24 x  14 x 512 ->   24 x  14 x 512 1.585 BF
#   27 conv    256       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 256 0.088 BF
#   28 conv    256       1 x 1/ 1     24 x  14 x 256 ->   24 x  14 x 256 0.044 BF
#   29 conv    512       3 x 3/ 1     24 x  14 x 256 ->   24 x  14 x 512 0.793 BF
#   30 conv    128       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 128 0.044 BF
#   31 upsample                 2x    24 x  14 x 128 ->   48 x  28 x 128
#   32 route  31 23 	                           ->   48 x  28 x 384
#   33 conv    128       1 x 1/ 1     48 x  28 x 384 ->   48 x  28 x 128 0.132 BF
#   34 conv    128       1 x 1/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.044 BF
#   35 conv    256       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 256 0.793 BF
#   36 conv    128       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.088 BF
#   37 upsample                 2x    48 x  28 x 128 ->   96 x  56 x 128
#   38 route  37 15 	                           ->   96 x  56 x 256
#   39 conv     64       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  64 0.176 BF
#   40 conv    256       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x 256 1.585 BF
#   41 route  0 		                           ->  384 x 224 x  32
#   42 avg                4x 4/ 4    384 x 224 x  32 ->   96 x  56 x  32 0.003 BF
#   43 route  42 40 	                           ->   96 x  56 x 288
#   44 conv    128       1 x 1/ 1     96 x  56 x 288 ->   96 x  56 x 128 0.396 BF
#   45 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   46 conv    128       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x 128 0.352 BF
#   47 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   48 conv   1152       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x1152 3.171 BF
#   49 route  40 		                           ->   96 x  56 x 256
#   50 conv    256       3 x 3/ 1     96 x  56 x 256 ->   96 x  56 x 256 6.342 BF
#   51 conv     63       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  63 0.173 BF
#   52 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#  embedding_layer_id = 48,  embedding_size = 128
#   53 route  48 		                           ->   96 x  56 x1152
#   54  max_contr_size = 0 MB
# contrastive   96 x  56 x   9 x emb_size  128 x batch:    1  classes =    2, step = 48384
# detection
# Total BFLOPS 31.950
# avg_outputs = 1067184
#  Allocate additional workspace_size = 26.22 MB
#  Try to load weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights
# Loading weights from backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights...
#  seen 64, trained: 640 K-images (10 Kilo-batches_64)
# Done! Loaded 55 layers from weights-file
# Loaded - names_list: /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/backup/20210920_yolov4_tiny_tracking/pets.names, classes = 2
# input video /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N061.mp4 with frame rate: 10.0 => skips 1 frame(s)
# Testing video 41 / 54
# Namespace(config_file='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg', data_file='backup/20210920_yolov4_tiny_tracking/pets.data', dont_show=False, ext_output=False, input_type='video', out_filename='', source_url='/content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N062.mp4', thresh=0.5, weights='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights')
#  Try to load cfg: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg, weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights, clear = 0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    768 x 448 x   3 ->  384 x 224 x  32 0.149 BF
#    1 conv     64       3 x 3/ 2    384 x 224 x  32 ->  192 x 112 x  64 0.793 BF
#    2 conv     64       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  64 1.585 BF
#    3 route  2 		                           ->  192 x 112 x  64
#    4 conv     32       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  32 0.793 BF
#    5 conv     32       3 x 3/ 1    192 x 112 x  32 ->  192 x 112 x  32 0.396 BF
#    6 route  5 4 	                           ->  192 x 112 x  64
#    7 conv     64       1 x 1/ 1    192 x 112 x  64 ->  192 x 112 x  64 0.176 BF
#    8 route  2 7 	                           ->  192 x 112 x 128
#    9 max                2x 2/ 2    192 x 112 x 128 ->   96 x  56 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 128 1.585 BF
#   11 route  10 		                           ->   96 x  56 x 128
#   12 conv     64       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x  64 0.793 BF
#   13 conv     64       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x  64 0.396 BF
#   14 route  13 12 	                           ->   96 x  56 x 128
#   15 conv    128       1 x 1/ 1     96 x  56 x 128 ->   96 x  56 x 128 0.176 BF
#   16 route  10 15 	                           ->   96 x  56 x 256
#   17 max                2x 2/ 2     96 x  56 x 256 ->   48 x  28 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 256 1.585 BF
#   19 route  18 		                           ->   48 x  28 x 256
#   20 conv    128       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.793 BF
#   21 conv    128       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.396 BF
#   22 route  21 20 	                           ->   48 x  28 x 256
#   23 conv    256       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 256 0.176 BF
#   24 route  18 23 	                           ->   48 x  28 x 512
#   25 max                2x 2/ 2     48 x  28 x 512 ->   24 x  14 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     24 x  14 x 512 ->   24 x  14 x 512 1.585 BF
#   27 conv    256       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 256 0.088 BF
#   28 conv    256       1 x 1/ 1     24 x  14 x 256 ->   24 x  14 x 256 0.044 BF
#   29 conv    512       3 x 3/ 1     24 x  14 x 256 ->   24 x  14 x 512 0.793 BF
#   30 conv    128       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 128 0.044 BF
#   31 upsample                 2x    24 x  14 x 128 ->   48 x  28 x 128
#   32 route  31 23 	                           ->   48 x  28 x 384
#   33 conv    128       1 x 1/ 1     48 x  28 x 384 ->   48 x  28 x 128 0.132 BF
#   34 conv    128       1 x 1/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.044 BF
#   35 conv    256       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 256 0.793 BF
#   36 conv    128       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.088 BF
#   37 upsample                 2x    48 x  28 x 128 ->   96 x  56 x 128
#   38 route  37 15 	                           ->   96 x  56 x 256
#   39 conv     64       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  64 0.176 BF
#   40 conv    256       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x 256 1.585 BF
#   41 route  0 		                           ->  384 x 224 x  32
#   42 avg                4x 4/ 4    384 x 224 x  32 ->   96 x  56 x  32 0.003 BF
#   43 route  42 40 	                           ->   96 x  56 x 288
#   44 conv    128       1 x 1/ 1     96 x  56 x 288 ->   96 x  56 x 128 0.396 BF
#   45 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   46 conv    128       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x 128 0.352 BF
#   47 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   48 conv   1152       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x1152 3.171 BF
#   49 route  40 		                           ->   96 x  56 x 256
#   50 conv    256       3 x 3/ 1     96 x  56 x 256 ->   96 x  56 x 256 6.342 BF
#   51 conv     63       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  63 0.173 BF
#   52 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#  embedding_layer_id = 48,  embedding_size = 128
#   53 route  48 		                           ->   96 x  56 x1152
#   54  max_contr_size = 0 MB
# contrastive   96 x  56 x   9 x emb_size  128 x batch:    1  classes =    2, step = 48384
# detection
# Total BFLOPS 31.950
# avg_outputs = 1067184
#  Allocate additional workspace_size = 26.22 MB
#  Try to load weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights
# Loading weights from backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights...
#  seen 64, trained: 640 K-images (10 Kilo-batches_64)
# Done! Loaded 55 layers from weights-file
# Loaded - names_list: /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/backup/20210920_yolov4_tiny_tracking/pets.names, classes = 2
# input video /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N062.mp4 with frame rate: 10.0 => skips 1 frame(s)
# Testing video 42 / 54
# Namespace(config_file='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg', data_file='backup/20210920_yolov4_tiny_tracking/pets.data', dont_show=False, ext_output=False, input_type='video', out_filename='', source_url='/content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N063.mp4', thresh=0.5, weights='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights')
#  Try to load cfg: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg, weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights, clear = 0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    768 x 448 x   3 ->  384 x 224 x  32 0.149 BF
#    1 conv     64       3 x 3/ 2    384 x 224 x  32 ->  192 x 112 x  64 0.793 BF
#    2 conv     64       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  64 1.585 BF
#    3 route  2 		                           ->  192 x 112 x  64
#    4 conv     32       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  32 0.793 BF
#    5 conv     32       3 x 3/ 1    192 x 112 x  32 ->  192 x 112 x  32 0.396 BF
#    6 route  5 4 	                           ->  192 x 112 x  64
#    7 conv     64       1 x 1/ 1    192 x 112 x  64 ->  192 x 112 x  64 0.176 BF
#    8 route  2 7 	                           ->  192 x 112 x 128
#    9 max                2x 2/ 2    192 x 112 x 128 ->   96 x  56 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 128 1.585 BF
#   11 route  10 		                           ->   96 x  56 x 128
#   12 conv     64       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x  64 0.793 BF
#   13 conv     64       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x  64 0.396 BF
#   14 route  13 12 	                           ->   96 x  56 x 128
#   15 conv    128       1 x 1/ 1     96 x  56 x 128 ->   96 x  56 x 128 0.176 BF
#   16 route  10 15 	                           ->   96 x  56 x 256
#   17 max                2x 2/ 2     96 x  56 x 256 ->   48 x  28 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 256 1.585 BF
#   19 route  18 		                           ->   48 x  28 x 256
#   20 conv    128       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.793 BF
#   21 conv    128       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.396 BF
#   22 route  21 20 	                           ->   48 x  28 x 256
#   23 conv    256       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 256 0.176 BF
#   24 route  18 23 	                           ->   48 x  28 x 512
#   25 max                2x 2/ 2     48 x  28 x 512 ->   24 x  14 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     24 x  14 x 512 ->   24 x  14 x 512 1.585 BF
#   27 conv    256       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 256 0.088 BF
#   28 conv    256       1 x 1/ 1     24 x  14 x 256 ->   24 x  14 x 256 0.044 BF
#   29 conv    512       3 x 3/ 1     24 x  14 x 256 ->   24 x  14 x 512 0.793 BF
#   30 conv    128       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 128 0.044 BF
#   31 upsample                 2x    24 x  14 x 128 ->   48 x  28 x 128
#   32 route  31 23 	                           ->   48 x  28 x 384
#   33 conv    128       1 x 1/ 1     48 x  28 x 384 ->   48 x  28 x 128 0.132 BF
#   34 conv    128       1 x 1/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.044 BF
#   35 conv    256       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 256 0.793 BF
#   36 conv    128       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.088 BF
#   37 upsample                 2x    48 x  28 x 128 ->   96 x  56 x 128
#   38 route  37 15 	                           ->   96 x  56 x 256
#   39 conv     64       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  64 0.176 BF
#   40 conv    256       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x 256 1.585 BF
#   41 route  0 		                           ->  384 x 224 x  32
#   42 avg                4x 4/ 4    384 x 224 x  32 ->   96 x  56 x  32 0.003 BF
#   43 route  42 40 	                           ->   96 x  56 x 288
#   44 conv    128       1 x 1/ 1     96 x  56 x 288 ->   96 x  56 x 128 0.396 BF
#   45 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   46 conv    128       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x 128 0.352 BF
#   47 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   48 conv   1152       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x1152 3.171 BF
#   49 route  40 		                           ->   96 x  56 x 256
#   50 conv    256       3 x 3/ 1     96 x  56 x 256 ->   96 x  56 x 256 6.342 BF
#   51 conv     63       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  63 0.173 BF
#   52 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#  embedding_layer_id = 48,  embedding_size = 128
#   53 route  48 		                           ->   96 x  56 x1152
#   54  max_contr_size = 0 MB
# contrastive   96 x  56 x   9 x emb_size  128 x batch:    1  classes =    2, step = 48384
# detection
# Total BFLOPS 31.950
# avg_outputs = 1067184
#  Allocate additional workspace_size = 26.22 MB
#  Try to load weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights
# Loading weights from backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights...
#  seen 64, trained: 640 K-images (10 Kilo-batches_64)
# Done! Loaded 55 layers from weights-file
# Loaded - names_list: /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/backup/20210920_yolov4_tiny_tracking/pets.names, classes = 2
# input video /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N063.mp4 with frame rate: 10.0 => skips 1 frame(s)
# Testing video 43 / 54
# Namespace(config_file='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg', data_file='backup/20210920_yolov4_tiny_tracking/pets.data', dont_show=False, ext_output=False, input_type='video', out_filename='', source_url='/content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N064.mp4', thresh=0.5, weights='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights')
#  Try to load cfg: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg, weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights, clear = 0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    768 x 448 x   3 ->  384 x 224 x  32 0.149 BF
#    1 conv     64       3 x 3/ 2    384 x 224 x  32 ->  192 x 112 x  64 0.793 BF
#    2 conv     64       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  64 1.585 BF
#    3 route  2 		                           ->  192 x 112 x  64
#    4 conv     32       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  32 0.793 BF
#    5 conv     32       3 x 3/ 1    192 x 112 x  32 ->  192 x 112 x  32 0.396 BF
#    6 route  5 4 	                           ->  192 x 112 x  64
#    7 conv     64       1 x 1/ 1    192 x 112 x  64 ->  192 x 112 x  64 0.176 BF
#    8 route  2 7 	                           ->  192 x 112 x 128
#    9 max                2x 2/ 2    192 x 112 x 128 ->   96 x  56 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 128 1.585 BF
#   11 route  10 		                           ->   96 x  56 x 128
#   12 conv     64       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x  64 0.793 BF
#   13 conv     64       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x  64 0.396 BF
#   14 route  13 12 	                           ->   96 x  56 x 128
#   15 conv    128       1 x 1/ 1     96 x  56 x 128 ->   96 x  56 x 128 0.176 BF
#   16 route  10 15 	                           ->   96 x  56 x 256
#   17 max                2x 2/ 2     96 x  56 x 256 ->   48 x  28 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 256 1.585 BF
#   19 route  18 		                           ->   48 x  28 x 256
#   20 conv    128       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.793 BF
#   21 conv    128       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.396 BF
#   22 route  21 20 	                           ->   48 x  28 x 256
#   23 conv    256       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 256 0.176 BF
#   24 route  18 23 	                           ->   48 x  28 x 512
#   25 max                2x 2/ 2     48 x  28 x 512 ->   24 x  14 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     24 x  14 x 512 ->   24 x  14 x 512 1.585 BF
#   27 conv    256       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 256 0.088 BF
#   28 conv    256       1 x 1/ 1     24 x  14 x 256 ->   24 x  14 x 256 0.044 BF
#   29 conv    512       3 x 3/ 1     24 x  14 x 256 ->   24 x  14 x 512 0.793 BF
#   30 conv    128       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 128 0.044 BF
#   31 upsample                 2x    24 x  14 x 128 ->   48 x  28 x 128
#   32 route  31 23 	                           ->   48 x  28 x 384
#   33 conv    128       1 x 1/ 1     48 x  28 x 384 ->   48 x  28 x 128 0.132 BF
#   34 conv    128       1 x 1/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.044 BF
#   35 conv    256       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 256 0.793 BF
#   36 conv    128       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.088 BF
#   37 upsample                 2x    48 x  28 x 128 ->   96 x  56 x 128
#   38 route  37 15 	                           ->   96 x  56 x 256
#   39 conv     64       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  64 0.176 BF
#   40 conv    256       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x 256 1.585 BF
#   41 route  0 		                           ->  384 x 224 x  32
#   42 avg                4x 4/ 4    384 x 224 x  32 ->   96 x  56 x  32 0.003 BF
#   43 route  42 40 	                           ->   96 x  56 x 288
#   44 conv    128       1 x 1/ 1     96 x  56 x 288 ->   96 x  56 x 128 0.396 BF
#   45 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   46 conv    128       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x 128 0.352 BF
#   47 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   48 conv   1152       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x1152 3.171 BF
#   49 route  40 		                           ->   96 x  56 x 256
#   50 conv    256       3 x 3/ 1     96 x  56 x 256 ->   96 x  56 x 256 6.342 BF
#   51 conv     63       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  63 0.173 BF
#   52 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#  embedding_layer_id = 48,  embedding_size = 128
#   53 route  48 		                           ->   96 x  56 x1152
#   54  max_contr_size = 0 MB
# contrastive   96 x  56 x   9 x emb_size  128 x batch:    1  classes =    2, step = 48384
# detection
# Total BFLOPS 31.950
# avg_outputs = 1067184
#  Allocate additional workspace_size = 26.22 MB
#  Try to load weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights
# Loading weights from backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights...
#  seen 64, trained: 640 K-images (10 Kilo-batches_64)
# Done! Loaded 55 layers from weights-file
# Loaded - names_list: /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/backup/20210920_yolov4_tiny_tracking/pets.names, classes = 2
# input video /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N064.mp4 with frame rate: 10.0 => skips 1 frame(s)
# Testing video 44 / 54
# Namespace(config_file='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg', data_file='backup/20210920_yolov4_tiny_tracking/pets.data', dont_show=False, ext_output=False, input_type='video', out_filename='', source_url='/content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N065.mp4', thresh=0.5, weights='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights')
#  Try to load cfg: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg, weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights, clear = 0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    768 x 448 x   3 ->  384 x 224 x  32 0.149 BF
#    1 conv     64       3 x 3/ 2    384 x 224 x  32 ->  192 x 112 x  64 0.793 BF
#    2 conv     64       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  64 1.585 BF
#    3 route  2 		                           ->  192 x 112 x  64
#    4 conv     32       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  32 0.793 BF
#    5 conv     32       3 x 3/ 1    192 x 112 x  32 ->  192 x 112 x  32 0.396 BF
#    6 route  5 4 	                           ->  192 x 112 x  64
#    7 conv     64       1 x 1/ 1    192 x 112 x  64 ->  192 x 112 x  64 0.176 BF
#    8 route  2 7 	                           ->  192 x 112 x 128
#    9 max                2x 2/ 2    192 x 112 x 128 ->   96 x  56 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 128 1.585 BF
#   11 route  10 		                           ->   96 x  56 x 128
#   12 conv     64       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x  64 0.793 BF
#   13 conv     64       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x  64 0.396 BF
#   14 route  13 12 	                           ->   96 x  56 x 128
#   15 conv    128       1 x 1/ 1     96 x  56 x 128 ->   96 x  56 x 128 0.176 BF
#   16 route  10 15 	                           ->   96 x  56 x 256
#   17 max                2x 2/ 2     96 x  56 x 256 ->   48 x  28 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 256 1.585 BF
#   19 route  18 		                           ->   48 x  28 x 256
#   20 conv    128       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.793 BF
#   21 conv    128       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.396 BF
#   22 route  21 20 	                           ->   48 x  28 x 256
#   23 conv    256       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 256 0.176 BF
#   24 route  18 23 	                           ->   48 x  28 x 512
#   25 max                2x 2/ 2     48 x  28 x 512 ->   24 x  14 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     24 x  14 x 512 ->   24 x  14 x 512 1.585 BF
#   27 conv    256       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 256 0.088 BF
#   28 conv    256       1 x 1/ 1     24 x  14 x 256 ->   24 x  14 x 256 0.044 BF
#   29 conv    512       3 x 3/ 1     24 x  14 x 256 ->   24 x  14 x 512 0.793 BF
#   30 conv    128       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 128 0.044 BF
#   31 upsample                 2x    24 x  14 x 128 ->   48 x  28 x 128
#   32 route  31 23 	                           ->   48 x  28 x 384
#   33 conv    128       1 x 1/ 1     48 x  28 x 384 ->   48 x  28 x 128 0.132 BF
#   34 conv    128       1 x 1/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.044 BF
#   35 conv    256       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 256 0.793 BF
#   36 conv    128       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.088 BF
#   37 upsample                 2x    48 x  28 x 128 ->   96 x  56 x 128
#   38 route  37 15 	                           ->   96 x  56 x 256
#   39 conv     64       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  64 0.176 BF
#   40 conv    256       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x 256 1.585 BF
#   41 route  0 		                           ->  384 x 224 x  32
#   42 avg                4x 4/ 4    384 x 224 x  32 ->   96 x  56 x  32 0.003 BF
#   43 route  42 40 	                           ->   96 x  56 x 288
#   44 conv    128       1 x 1/ 1     96 x  56 x 288 ->   96 x  56 x 128 0.396 BF
#   45 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   46 conv    128       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x 128 0.352 BF
#   47 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   48 conv   1152       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x1152 3.171 BF
#   49 route  40 		                           ->   96 x  56 x 256
#   50 conv    256       3 x 3/ 1     96 x  56 x 256 ->   96 x  56 x 256 6.342 BF
#   51 conv     63       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  63 0.173 BF
#   52 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#  embedding_layer_id = 48,  embedding_size = 128
#   53 route  48 		                           ->   96 x  56 x1152
#   54  max_contr_size = 0 MB
# contrastive   96 x  56 x   9 x emb_size  128 x batch:    1  classes =    2, step = 48384
# detection
# Total BFLOPS 31.950
# avg_outputs = 1067184
#  Allocate additional workspace_size = 26.22 MB
#  Try to load weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights
# Loading weights from backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights...
#  seen 64, trained: 640 K-images (10 Kilo-batches_64)
# Done! Loaded 55 layers from weights-file
# Loaded - names_list: /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/backup/20210920_yolov4_tiny_tracking/pets.names, classes = 2
# input video /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N065.mp4 with frame rate: 10.0 => skips 1 frame(s)
# Testing video 45 / 54
# Namespace(config_file='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg', data_file='backup/20210920_yolov4_tiny_tracking/pets.data', dont_show=False, ext_output=False, input_type='video', out_filename='', source_url='/content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N066.mp4', thresh=0.5, weights='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights')
#  Try to load cfg: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg, weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights, clear = 0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    768 x 448 x   3 ->  384 x 224 x  32 0.149 BF
#    1 conv     64       3 x 3/ 2    384 x 224 x  32 ->  192 x 112 x  64 0.793 BF
#    2 conv     64       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  64 1.585 BF
#    3 route  2 		                           ->  192 x 112 x  64
#    4 conv     32       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  32 0.793 BF
#    5 conv     32       3 x 3/ 1    192 x 112 x  32 ->  192 x 112 x  32 0.396 BF
#    6 route  5 4 	                           ->  192 x 112 x  64
#    7 conv     64       1 x 1/ 1    192 x 112 x  64 ->  192 x 112 x  64 0.176 BF
#    8 route  2 7 	                           ->  192 x 112 x 128
#    9 max                2x 2/ 2    192 x 112 x 128 ->   96 x  56 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 128 1.585 BF
#   11 route  10 		                           ->   96 x  56 x 128
#   12 conv     64       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x  64 0.793 BF
#   13 conv     64       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x  64 0.396 BF
#   14 route  13 12 	                           ->   96 x  56 x 128
#   15 conv    128       1 x 1/ 1     96 x  56 x 128 ->   96 x  56 x 128 0.176 BF
#   16 route  10 15 	                           ->   96 x  56 x 256
#   17 max                2x 2/ 2     96 x  56 x 256 ->   48 x  28 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 256 1.585 BF
#   19 route  18 		                           ->   48 x  28 x 256
#   20 conv    128       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.793 BF
#   21 conv    128       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.396 BF
#   22 route  21 20 	                           ->   48 x  28 x 256
#   23 conv    256       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 256 0.176 BF
#   24 route  18 23 	                           ->   48 x  28 x 512
#   25 max                2x 2/ 2     48 x  28 x 512 ->   24 x  14 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     24 x  14 x 512 ->   24 x  14 x 512 1.585 BF
#   27 conv    256       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 256 0.088 BF
#   28 conv    256       1 x 1/ 1     24 x  14 x 256 ->   24 x  14 x 256 0.044 BF
#   29 conv    512       3 x 3/ 1     24 x  14 x 256 ->   24 x  14 x 512 0.793 BF
#   30 conv    128       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 128 0.044 BF
#   31 upsample                 2x    24 x  14 x 128 ->   48 x  28 x 128
#   32 route  31 23 	                           ->   48 x  28 x 384
#   33 conv    128       1 x 1/ 1     48 x  28 x 384 ->   48 x  28 x 128 0.132 BF
#   34 conv    128       1 x 1/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.044 BF
#   35 conv    256       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 256 0.793 BF
#   36 conv    128       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.088 BF
#   37 upsample                 2x    48 x  28 x 128 ->   96 x  56 x 128
#   38 route  37 15 	                           ->   96 x  56 x 256
#   39 conv     64       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  64 0.176 BF
#   40 conv    256       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x 256 1.585 BF
#   41 route  0 		                           ->  384 x 224 x  32
#   42 avg                4x 4/ 4    384 x 224 x  32 ->   96 x  56 x  32 0.003 BF
#   43 route  42 40 	                           ->   96 x  56 x 288
#   44 conv    128       1 x 1/ 1     96 x  56 x 288 ->   96 x  56 x 128 0.396 BF
#   45 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   46 conv    128       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x 128 0.352 BF
#   47 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   48 conv   1152       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x1152 3.171 BF
#   49 route  40 		                           ->   96 x  56 x 256
#   50 conv    256       3 x 3/ 1     96 x  56 x 256 ->   96 x  56 x 256 6.342 BF
#   51 conv     63       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  63 0.173 BF
#   52 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#  embedding_layer_id = 48,  embedding_size = 128
#   53 route  48 		                           ->   96 x  56 x1152
#   54  max_contr_size = 0 MB
# contrastive   96 x  56 x   9 x emb_size  128 x batch:    1  classes =    2, step = 48384
# detection
# Total BFLOPS 31.950
# avg_outputs = 1067184
#  Allocate additional workspace_size = 26.22 MB
#  Try to load weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights
# Loading weights from backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights...
#  seen 64, trained: 640 K-images (10 Kilo-batches_64)
# Done! Loaded 55 layers from weights-file
# Loaded - names_list: /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/backup/20210920_yolov4_tiny_tracking/pets.names, classes = 2
# input video /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N066.mp4 with frame rate: 10.0 => skips 1 frame(s)
# Testing video 46 / 54
# Namespace(config_file='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg', data_file='backup/20210920_yolov4_tiny_tracking/pets.data', dont_show=False, ext_output=False, input_type='video', out_filename='', source_url='/content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Negative/Pet_Pub_N067.mp4', thresh=0.5, weights='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights')
#  Try to load cfg: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg, weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights, clear = 0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    768 x 448 x   3 ->  384 x 224 x  32 0.149 BF
#    1 conv     64       3 x 3/ 2    384 x 224 x  32 ->  192 x 112 x  64 0.793 BF
#    2 conv     64       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  64 1.585 BF
#    3 route  2 		                           ->  192 x 112 x  64
#    4 conv     32       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  32 0.793 BF
#    5 conv     32       3 x 3/ 1    192 x 112 x  32 ->  192 x 112 x  32 0.396 BF
#    6 route  5 4 	                           ->  192 x 112 x  64
#    7 conv     64       1 x 1/ 1    192 x 112 x  64 ->  192 x 112 x  64 0.176 BF
#    8 route  2 7 	                           ->  192 x 112 x 128
#    9 max                2x 2/ 2    192 x 112 x 128 ->   96 x  56 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 128 1.585 BF
#   11 route  10 		                           ->   96 x  56 x 128
#   12 conv     64       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x  64 0.793 BF
#   13 conv     64       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x  64 0.396 BF
#   14 route  13 12 	                           ->   96 x  56 x 128
#   15 conv    128       1 x 1/ 1     96 x  56 x 128 ->   96 x  56 x 128 0.176 BF
#   16 route  10 15 	                           ->   96 x  56 x 256
#   17 max                2x 2/ 2     96 x  56 x 256 ->   48 x  28 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 256 1.585 BF
#   19 route  18 		                           ->   48 x  28 x 256
#   20 conv    128       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.793 BF
#   21 conv    128       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.396 BF
#   22 route  21 20 	                           ->   48 x  28 x 256
#   23 conv    256       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 256 0.176 BF
#   24 route  18 23 	                           ->   48 x  28 x 512
#   25 max                2x 2/ 2     48 x  28 x 512 ->   24 x  14 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     24 x  14 x 512 ->   24 x  14 x 512 1.585 BF
#   27 conv    256       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 256 0.088 BF
#   28 conv    256       1 x 1/ 1     24 x  14 x 256 ->   24 x  14 x 256 0.044 BF
#   29 conv    512       3 x 3/ 1     24 x  14 x 256 ->   24 x  14 x 512 0.793 BF
#   30 conv    128       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 128 0.044 BF
#   31 upsample                 2x    24 x  14 x 128 ->   48 x  28 x 128
# ...
#   30 conv    128       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 128 0.044 BF
#   31 upsample                 2x    24 x  14 x 128 ->   48 x  28 x 128
#   32 route  31 23 	                           ->   48 x  28 x 384
#   33 conv    128       1 x 1/ 1     48 x  28 x 384 ->   48 x  28 x 128 0.132 BF
#   34 conv    128       1 x 1/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.044 BF
#   35 conv    256       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 256 0.793 BF
#   36 conv    128       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.088 BF
#   37 upsample                 2x    48 x  28 x 128 ->   96 x  56 x 128
#   38 route  37 15 	                           ->   96 x  56 x 256
#   39 conv     64       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  64 0.176 BF
#   40 conv    256       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x 256 1.585 BF
#   41 route  0 		                           ->  384 x 224 x  32
#   42 avg                4x 4/ 4    384 x 224 x  32 ->   96 x  56 x  32 0.003 BF
#   43 route  42 40 	                           ->   96 x  56 x 288
#   44 conv    128       1 x 1/ 1     96 x  56 x 288 ->   96 x  56 x 128 0.396 BF
#   45 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   46 conv    128       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x 128 0.352 BF
#   47 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   48 conv   1152       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x1152 3.171 BF
#   49 route  40 		                           ->   96 x  56 x 256
#   50 conv    256       3 x 3/ 1     96 x  56 x 256 ->   96 x  56 x 256 6.342 BF
#   51 conv     63       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  63 0.173 BF
#   52 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#  embedding_layer_id = 48,  embedding_size = 128
#   53 route  48 		                           ->   96 x  56 x1152
#   54  max_contr_size = 0 MB
# contrastive   96 x  56 x   9 x emb_size  128 x batch:    1  classes =    2, step = 48384
# detection
# Total BFLOPS 31.950
# avg_outputs = 1067184
#  Allocate additional workspace_size = 26.22 MB
#  Try to load weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights
# Loading weights from backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights...
#  seen 64, trained: 640 K-images (10 Kilo-batches_64)
# Done! Loaded 55 layers from weights-file
# Loaded - names_list: /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/backup/20210920_yolov4_tiny_tracking/pets.names, classes = 2
# input video /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Positive/Pet_Pub_P044.mp4 with frame rate: 10.0 => skips 1 frame(s)
# [Warning!] at time 20210922_054611 Pet(s) were detected!
# [Warning!] at time 20210922_054612 Pet(s) were detected!
# [Warning!] at time 20210922_054613 Pet(s) were detected!
# [Warning!] at time 20210922_054615 Pet(s) were detected!
# [Warning!] at time 20210922_054616 Pet(s) were detected!
# Testing video 45 / 46
# Namespace(config_file='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg', data_file='backup/20210920_yolov4_tiny_tracking/pets.data', dont_show=False, ext_output=False, input_type='video', out_filename='', source_url='/content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Positive/Pet_Pub_P045.mp4', thresh=0.25, weights='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights')
#  Try to load cfg: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg, weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights, clear = 0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    768 x 448 x   3 ->  384 x 224 x  32 0.149 BF
#    1 conv     64       3 x 3/ 2    384 x 224 x  32 ->  192 x 112 x  64 0.793 BF
#    2 conv     64       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  64 1.585 BF
#    3 route  2 		                           ->  192 x 112 x  64
#    4 conv     32       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  32 0.793 BF
#    5 conv     32       3 x 3/ 1    192 x 112 x  32 ->  192 x 112 x  32 0.396 BF
#    6 route  5 4 	                           ->  192 x 112 x  64
#    7 conv     64       1 x 1/ 1    192 x 112 x  64 ->  192 x 112 x  64 0.176 BF
#    8 route  2 7 	                           ->  192 x 112 x 128
#    9 max                2x 2/ 2    192 x 112 x 128 ->   96 x  56 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 128 1.585 BF
#   11 route  10 		                           ->   96 x  56 x 128
#   12 conv     64       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x  64 0.793 BF
#   13 conv     64       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x  64 0.396 BF
#   14 route  13 12 	                           ->   96 x  56 x 128
#   15 conv    128       1 x 1/ 1     96 x  56 x 128 ->   96 x  56 x 128 0.176 BF
#   16 route  10 15 	                           ->   96 x  56 x 256
#   17 max                2x 2/ 2     96 x  56 x 256 ->   48 x  28 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 256 1.585 BF
#   19 route  18 		                           ->   48 x  28 x 256
#   20 conv    128       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.793 BF
#   21 conv    128       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.396 BF
#   22 route  21 20 	                           ->   48 x  28 x 256
#   23 conv    256       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 256 0.176 BF
#   24 route  18 23 	                           ->   48 x  28 x 512
#   25 max                2x 2/ 2     48 x  28 x 512 ->   24 x  14 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     24 x  14 x 512 ->   24 x  14 x 512 1.585 BF
#   27 conv    256       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 256 0.088 BF
#   28 conv    256       1 x 1/ 1     24 x  14 x 256 ->   24 x  14 x 256 0.044 BF
#   29 conv    512       3 x 3/ 1     24 x  14 x 256 ->   24 x  14 x 512 0.793 BF
#   30 conv    128       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 128 0.044 BF
#   31 upsample                 2x    24 x  14 x 128 ->   48 x  28 x 128
#   32 route  31 23 	                           ->   48 x  28 x 384
#   33 conv    128       1 x 1/ 1     48 x  28 x 384 ->   48 x  28 x 128 0.132 BF
#   34 conv    128       1 x 1/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.044 BF
#   35 conv    256       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 256 0.793 BF
#   36 conv    128       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.088 BF
#   37 upsample                 2x    48 x  28 x 128 ->   96 x  56 x 128
#   38 route  37 15 	                           ->   96 x  56 x 256
#   39 conv     64       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  64 0.176 BF
#   40 conv    256       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x 256 1.585 BF
#   41 route  0 		                           ->  384 x 224 x  32
#   42 avg                4x 4/ 4    384 x 224 x  32 ->   96 x  56 x  32 0.003 BF
#   43 route  42 40 	                           ->   96 x  56 x 288
#   44 conv    128       1 x 1/ 1     96 x  56 x 288 ->   96 x  56 x 128 0.396 BF
#   45 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   46 conv    128       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x 128 0.352 BF
#   47 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   48 conv   1152       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x1152 3.171 BF
#   49 route  40 		                           ->   96 x  56 x 256
#   50 conv    256       3 x 3/ 1     96 x  56 x 256 ->   96 x  56 x 256 6.342 BF
#   51 conv     63       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  63 0.173 BF
#   52 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#  embedding_layer_id = 48,  embedding_size = 128
#   53 route  48 		                           ->   96 x  56 x1152
#   54  max_contr_size = 0 MB
# contrastive   96 x  56 x   9 x emb_size  128 x batch:    1  classes =    2, step = 48384
# detection
# Total BFLOPS 31.950
# avg_outputs = 1067184
#  Allocate additional workspace_size = 26.22 MB
#  Try to load weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights
# Loading weights from backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights...
#  seen 64, trained: 640 K-images (10 Kilo-batches_64)
# Done! Loaded 55 layers from weights-file
# Loaded - names_list: /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/backup/20210920_yolov4_tiny_tracking/pets.names, classes = 2
# input video /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Positive/Pet_Pub_P045.mp4 with frame rate: 10.0 => skips 1 frame(s)
# [Warning!] at time 20210922_054629 Pet(s) were detected!
# [Warning!] at time 20210922_054630 Pet(s) were detected!
# [Warning!] at time 20210922_054630 Pet(s) were detected!
# [Warning!] at time 20210922_054631 Pet(s) were detected!
# [Warning!] at time 20210922_054631 Pet(s) were detected!
# [Warning!] at time 20210922_054636 Pet(s) were detected!
# [Warning!] at time 20210922_054636 Pet(s) were detected!
# [Warning!] at time 20210922_054637 Pet(s) were detected!
# [Warning!] at time 20210922_054637 Pet(s) were detected!
# [Warning!] at time 20210922_054637 Pet(s) were detected!
# [Warning!] at time 20210922_054638 Pet(s) were detected!
# Testing video 46 / 46
# Namespace(config_file='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg', data_file='backup/20210920_yolov4_tiny_tracking/pets.data', dont_show=False, ext_output=False, input_type='video', out_filename='', source_url='/content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Positive/Pet_Pub_P046.mp4', thresh=0.25, weights='backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights')
#  Try to load cfg: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive.cfg, weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights, clear = 0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 2, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    768 x 448 x   3 ->  384 x 224 x  32 0.149 BF
#    1 conv     64       3 x 3/ 2    384 x 224 x  32 ->  192 x 112 x  64 0.793 BF
#    2 conv     64       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  64 1.585 BF
#    3 route  2 		                           ->  192 x 112 x  64
#    4 conv     32       3 x 3/ 1    192 x 112 x  64 ->  192 x 112 x  32 0.793 BF
#    5 conv     32       3 x 3/ 1    192 x 112 x  32 ->  192 x 112 x  32 0.396 BF
#    6 route  5 4 	                           ->  192 x 112 x  64
#    7 conv     64       1 x 1/ 1    192 x 112 x  64 ->  192 x 112 x  64 0.176 BF
#    8 route  2 7 	                           ->  192 x 112 x 128
#    9 max                2x 2/ 2    192 x 112 x 128 ->   96 x  56 x 128 0.003 BF
#   10 conv    128       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 128 1.585 BF
#   11 route  10 		                           ->   96 x  56 x 128
#   12 conv     64       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x  64 0.793 BF
#   13 conv     64       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x  64 0.396 BF
#   14 route  13 12 	                           ->   96 x  56 x 128
#   15 conv    128       1 x 1/ 1     96 x  56 x 128 ->   96 x  56 x 128 0.176 BF
#   16 route  10 15 	                           ->   96 x  56 x 256
#   17 max                2x 2/ 2     96 x  56 x 256 ->   48 x  28 x 256 0.001 BF
#   18 conv    256       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 256 1.585 BF
#   19 route  18 		                           ->   48 x  28 x 256
#   20 conv    128       3 x 3/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.793 BF
#   21 conv    128       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.396 BF
#   22 route  21 20 	                           ->   48 x  28 x 256
#   23 conv    256       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 256 0.176 BF
#   24 route  18 23 	                           ->   48 x  28 x 512
#   25 max                2x 2/ 2     48 x  28 x 512 ->   24 x  14 x 512 0.001 BF
#   26 conv    512       3 x 3/ 1     24 x  14 x 512 ->   24 x  14 x 512 1.585 BF
#   27 conv    256       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 256 0.088 BF
#   28 conv    256       1 x 1/ 1     24 x  14 x 256 ->   24 x  14 x 256 0.044 BF
#   29 conv    512       3 x 3/ 1     24 x  14 x 256 ->   24 x  14 x 512 0.793 BF
#   30 conv    128       1 x 1/ 1     24 x  14 x 512 ->   24 x  14 x 128 0.044 BF
#   31 upsample                 2x    24 x  14 x 128 ->   48 x  28 x 128
#   32 route  31 23 	                           ->   48 x  28 x 384
#   33 conv    128       1 x 1/ 1     48 x  28 x 384 ->   48 x  28 x 128 0.132 BF
#   34 conv    128       1 x 1/ 1     48 x  28 x 128 ->   48 x  28 x 128 0.044 BF
#   35 conv    256       3 x 3/ 1     48 x  28 x 128 ->   48 x  28 x 256 0.793 BF
#   36 conv    128       1 x 1/ 1     48 x  28 x 256 ->   48 x  28 x 128 0.088 BF
#   37 upsample                 2x    48 x  28 x 128 ->   96 x  56 x 128
#   38 route  37 15 	                           ->   96 x  56 x 256
#   39 conv     64       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  64 0.176 BF
#   40 conv    256       3 x 3/ 1     96 x  56 x  64 ->   96 x  56 x 256 1.585 BF
#   41 route  0 		                           ->  384 x 224 x  32
#   42 avg                4x 4/ 4    384 x 224 x  32 ->   96 x  56 x  32 0.003 BF
#   43 route  42 40 	                           ->   96 x  56 x 288
#   44 conv    128       1 x 1/ 1     96 x  56 x 288 ->   96 x  56 x 128 0.396 BF
#   45 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   46 conv    128       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x 128 0.352 BF
#   47 conv    256       3 x 3/ 1     96 x  56 x 128 ->   96 x  56 x 256 3.171 BF
#   48 conv   1152       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x1152 3.171 BF
#   49 route  40 		                           ->   96 x  56 x 256
#   50 conv    256       3 x 3/ 1     96 x  56 x 256 ->   96 x  56 x 256 6.342 BF
#   51 conv     63       1 x 1/ 1     96 x  56 x 256 ->   96 x  56 x  63 0.173 BF
#   52 yolo
# [yolo] params: iou loss: ciou (4), iou_norm: 0.07, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.05
# nms_kind: greedynms (1), beta = 0.600000
#  embedding_layer_id = 48,  embedding_size = 128
#   53 route  48 		                           ->   96 x  56 x1152
#   54  max_contr_size = 0 MB
# contrastive   96 x  56 x   9 x emb_size  128 x batch:    1  classes =    2, step = 48384
# detection
# Total BFLOPS 31.950
# avg_outputs = 1067184
#  Allocate additional workspace_size = 26.22 MB
#  Try to load weights: backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights
# Loading weights from backup/20210920_yolov4_tiny_tracking/yolov4-tiny_contrastive_40000.weights...
#  seen 64, trained: 640 K-images (10 Kilo-batches_64)
# Done! Loaded 55 layers from weights-file
# Loaded - names_list: /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/pets_detection_darknet/backup/20210920_yolov4_tiny_tracking/pets.names, classes = 2
# input video /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/Positive/Pet_Pub_P046.mp4 with frame rate: 10.0 => skips 1 frame(s)
# [Warning!] at time 20210922_054653 Pet(s) were detected!
# [Warning!] at time 20210922_054654 Pet(s) were detected!
# [Warning!] at time 20210922_054654 Pet(s) were detected!
# [Warning!] at time 20210922_054655 Pet(s) were detected!
