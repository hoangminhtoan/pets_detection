# %% [markdown]
# #Step 1. Mount to google drive folder

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !uname -a
# !nvidia-smi
# Out:
# Linux b6ffe3a01d12 5.4.104+ #1 SMP Sat Jun 5 09:50:34 PDT 2021 x86_64 x86_64 x86_64 GNU/Linux
# Mon Sep 13 01:38:47 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# ...

# %% [markdown]
# # Step 2. Create directory to test video files

# %%
# %cd /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/FalseAlarm/pets_210906/

import os 

for video_file in sorted(os.listdir(os.getcwd())):
    if '.mp4' in video_file and '._' not in video_file:
        with open('../dcm.txt', 'a') as fin:
            fin.write(f'"{os.getcwd()}/{video_file}"\n')
# Out:
# /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/FalseAlarm/pets_210906

# %% [markdown]
# # Step 3: Run bash scripts

# %%
# %cd /content/drive/MyDrive/VINBRAINS/Projects/SmartCity/Pets/Source_Code/yolov5/vsm_fp/

#!bash run_detect_online_n.sh
#!bash run_detect_online_p.sh
#!bash 20210806_run_detect_online_fp.sh
#!bash 20210812_run_detect_online_fp.sh
#!bash 20210816_run_detect_online_fp.sh
#!bash 20210819_run_detect_online_fp.sh
#!bash 20210823_run_detect_online_fp.sh
#!bash 20210831_run_detect_online_fp.sh
#!bash 20210903_run_detect_online_fp.sh
#!bash 20210906_run_detect_online_fp.sh
# !bash 20210912_run_detect_online_fp.sh
# Out:
# /content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Source_Code/yolov5/vsm_fp
# Number of testing video is : 1
# Testing image 1 / 1
# Namespace(classes=None, conf_thres=0.6, half=True, img_size=608, input_type='image', iou_thres=0.45, source_url='/content/drive/MyDrive/Personal_Docs/ToanHM/VINBRAINS/Projects/SmartCity/Pets/Datasets/FalseAlarm/pets_210912/', weights='../weights/20210825_5s/best.pt')
# Fusing layers...
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 100% 1/1 [00:00<00:00, 28532.68it/s]
# Number of testing video is : 1
# Testing video 1 / 1
# ...
